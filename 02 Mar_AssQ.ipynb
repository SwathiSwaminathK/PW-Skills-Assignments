# %% [markdown]
# **Q1:** What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.
#
# **Ans:**
#
# Matplotlib is a popular Python library used for creating high-quality visualizations and plots. It is a powerful tool that allows users to create a wide range of 2D and 3D plots and charts.
#
#
# Matplotlib is used for data visualization and exploratory data analysis in various fields, including scientific research, engineering, finance, and data science. It provides a wide range of customizable plot types, along with extensive options for customizing plot appearance, annotations, and labels.
#
#
# Five plots that can be plotted using the Pyplot module of Matplotlib:
#
#
# 1. Line plot: A line plot is a plot where data points are connected by straight lines. It is used to show trends and patterns in data over time or across different variables.
#
#
# 2. Bar plot: A bar plot is a plot where bars of equal width are used to represent different categories of data. It is used to compare the values of different categories of data.
#
#
# 3. Scatter plot: A scatter plot is a plot where data points are represented as points on a graph. It is used to show the relationship between two variables.
#
#
# 4. Histogram: A histogram is a plot where the distribution of a dataset is shown using bars of different heights. It is used to show the frequency distribution of a continuous variable.
#
#
# 5. Pie chart: A pie chart is a circular plot where the different categories of data are represented as slices of a pie. It is used to show the proportion of different categories in a dataset.

# %% [markdown]
# **Q2:** What is a scatter plot? Use the following code to generate data for x and y.
#
# Using this generated data plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.
#
# **Ans:**
#
# A scatter plot is a plot where data points are represented as points on a graph. It is used to show the relationship between two variables.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x, y)
plt.title("Scatter Plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %% [markdown]
# **Q3:** Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])
#
# **Ans:**
#
# The subplot() function is used to create multiple plots in a single figure. It is helpful when we want to visualize multiple plots simultaneously to compare and contrast them. It takes three arguments: the number of rows, the number of columns, and the plot number.

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

fig, axs = plt.subplots(2, 2)

axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Line Plot 1')

axs[0, 1].plot(x2, y2)
axs[0, 1].set_title('Line Plot 2')

axs[1, 0].plot(x3, y3)
axs[1, 0].set_title('Line Plot 3')

axs[1, 1].plot(x4, y4)
axs[1, 1].set_title('Line Plot 4')

fig.suptitle('Four Line Plots')

plt.subplots_adjust(hspace=0.5, wspace=0.3)

plt.show()

# %% [markdown]
# **Q4:** What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])
#
# **Ans:**
#
# A bar plot is a plot that represents data using rectangular bars. The length of each bar is proportional to the value of the data it represents. Bar plots are used to compare different categories or groups of data.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company, profit)
plt.title('Company Profit')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.show()

plt.barh(company, profit)
plt.title('Company Profit')
plt.xlabel('Profit')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# **Q5:** What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)
#
# **Ans:**
#
# A box plot is a graphical representation of the distribution of a dataset through their quartiles. It is a standardized way of displaying the distribution of data based on five main summary statistics: minimum, first quartile, median, third quartile, and maximum. The box represents the middle 50% of the data, while the whiskers extend to the minimum and maximum values within 1.5 times the interquartile range (IQR) of the first and third quartiles. Outliers are represented by individual points outside the whiskers.

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
d = [box1, box2]
plt.boxplot(d)
plt.title('Box Plot')
plt.xlabel('Data')
plt.ylabel('Values')
plt.show()
